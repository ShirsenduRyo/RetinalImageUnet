# %%
import tensorflow as tf

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
img_width = 256
img_height = 256
img_channels = 1

# %% [markdown]
# # Custom for a specific Problem

# %% [markdown]
# ## Importing the Libraries

# %%
import os
import random
import numpy as np
 
from tqdm import tqdm 

from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting the path

# %%
train_path = "D:\\Data sets\\DRIVE\\training"
train_ids = next(os.walk("processed"))[2]
gt_ids = next(os.walk(train_path + "\\1st_manual"))[2]

test_ids = next(os.walk(test_path + "\images"))[2]

# %%
train_ids[:5], gt_ids[:5], test_ids[:5]
# Out:
# (['Train21.tif', 'Train22.tif', 'Train23.tif', 'Train24.tif', 'Train25.tif'],
#  ['21_manual1.gif',
#   '22_manual1.gif',
#   '23_manual1.gif',
#   '24_manual1.gif',
#   '25_manual1.gif'],
#  ['01_test.tif', '02_test.tif', '03_test.tif', '04_test.tif', '05_test.tif'])

# %% [markdown]
# ## Setting the train and test

# %%
import gif2numpy
import cv2

# %%
from skimage.filters import threshold_otsu
thresh = 0

# %%
def gtImageDis(gt_path):
    frames, exts, image_specs = gif2numpy.convert(gt_path)
    frames = np.array(frames)
    labeled_img = frames.reshape(584, 565,3)
    labeled_img_dis = cv2.cvtColor(labeled_img, cv2.COLOR_BGR2GRAY)
    binary = labeled_img_dis > thresh
    return binary

# %%
X_train = np.zeros((len(train_ids), img_height, img_width), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), img_height, img_width), dtype=np.bool)

# %%
print('Resizing training images and masks')
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):   
    path ="processed\\" +id_
    img = imread(path,plugin="pil")[:,:]  
    img = resize(img, (img_height, img_width), mode='constant', preserve_range=True)
    
    X_train[n] = img  #Fill empty X_train with values from img
            
    gt_path = train_path+ "\\1st_manual\\" + gt_ids[n]
    gt_img = gtImageDis(gt_path)
    
    gt_img = resize(gt_img, (img_height, img_width), mode='constant', preserve_range=True)
    Y_train[n] = gt_img
    
print("Done")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Resizing training images and masks
# 100%|██████████| 20/20 [00:07<00:00,  2.73it/s]
# Done

# %%
unique, counts = np.unique(Y_train, return_counts=True)
dict(zip(unique, counts))
# Out:
# {False: 1197419, True: 113301}

# %%
X_test = np.zeros((len(test_ids), img_height, img_width, img_channels), dtype=np.uint8)
sizes_test = []

# %%
# test images
print('Resizing test images') 
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = test_path +"\\images\\" +id_
    img = imread(path,plugin="pil")[:,:,:img_channels]  
    img = resize(img, (img_height, img_width), mode='constant', preserve_range=True)

    X_test[n] = img

print('Done!')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Resizing test images
# 100%|██████████| 20/20 [00:01<00:00, 15.10it/s]
# Done!

# %% [markdown]
# ## Preview of the Work Done Till Now

# %%
image_x = random.randint(0, len(train_ids))
imshow(X_train[image_x])
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()

# %% [markdown]
# # The Model

# %%
norm_inputs = tf.keras.layers.Input((img_height, img_width,1))
inputs = tf.keras.layers.Lambda(lambda x: x/255)(norm_inputs)

# %%
inputs
# Out:
# <KerasTensor: shape=(None, 256, 256, 1) dtype=float32 (created by layer 'lambda_1')>

# %% [markdown]
# ## Contraction Path

# %%
c1 = tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(c1)
p1 = tf.keras.layers.MaxPool2D((2,2))(c1)

# %%
c2 = tf.keras.layers.Conv2D(32, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(c2)
p2 = tf.keras.layers.MaxPool2D((2,2))(c2)

# %%
c3 = tf.keras.layers.Conv2D(64, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(p2)
c3 = tf.keras.layers.Dropout(0.1)(c3)
c3 = tf.keras.layers.Conv2D(64, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(c3)
p3 = tf.keras.layers.MaxPool2D((2,2))(c3)

# %%
c4 = tf.keras.layers.Conv2D(128, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(p3)
c4 = tf.keras.layers.Dropout(0.1)(c4)
c4 = tf.keras.layers.Conv2D(128, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(c4)
p4 = tf.keras.layers.MaxPool2D((2,2))(c4)

# %%
c5 = tf.keras.layers.Conv2D(256, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(p4)
c5 = tf.keras.layers.Dropout(0.1)(c5)
c5 = tf.keras.layers.Conv2D(256, (3,3), activation = 'relu', kernel_initializer='he_normal', padding = 'same' )(c5)
p5 = tf.keras.layers.MaxPool2D((2,2))(c5)

# %% [markdown]
# ## Expansive Path

# %%
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
c6 = tf.keras.layers.Dropout(0.2)(c6)
c6 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)

# %%
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
u7 = tf.keras.layers.concatenate([u7, c3])
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
c7 = tf.keras.layers.Dropout(0.2)(c7)
c7 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)

# %%
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
u8 = tf.keras.layers.concatenate([u8, c2])
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
c8 = tf.keras.layers.Dropout(0.1)(c8)
c8 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)

# %%
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
c9 = tf.keras.layers.Dropout(0.1)(c9)
c9 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)

# %% [markdown]
# ## Model Compilation

# %%
outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

# %%
model = tf.keras.Model(inputs=[norm_inputs], outputs=[outputs])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 1) 0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 1)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 16) 160         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256, 256, 16) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 16) 2320        dropout[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 16) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 32) 4640        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128, 128, 32) 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 32) 9248        dropout_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64, 64, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 32, 32, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  147584      dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 16, 16, 256)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 256)  590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 128)  131200      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d_transpose[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 32, 32, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 128)  147584      dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 64)   32832       conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 64, 64, 64)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   36928       dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 8224        conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 128, 128, 32) 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 9248        dropout_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 16) 2064        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 32) 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 16) 4624        concatenate_3[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256, 256, 16) 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 16) 2320        dropout_8[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 1)  17          conv2d_18[0][0]
# ==================================================================================================
# Total params: 1,940,817
# Trainable params: 1,940,817
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Check Point

# %%
checkpointer = tf.keras.callbacks.ModelCheckpoint("u_net_model.h5", verbose=1, save_best_only=True)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss'),
    #tf.keras.callbacks.TensorBoard(log_dir = 'logs')
]

# %%
es = tf.keras.callbacks.EarlyStopping(patience=2, monitor='val_loss')
tboard = tf.keras.callbacks.TensorBoard(log_dir = 'logs')

# %% [markdown]
# # Results

# %%
results = model.fit(X_train, Y_train, validation_split=0.1, batch_size=8, epochs=25, callbacks=callbacks)
# Out:
# Epoch 1/25
# 3/3 [==============================] - 44s 1s/step - loss: 0.6389 - accuracy: 0.8091 - val_loss: 0.6191 - val_accuracy: 0.9144
# Epoch 2/25
# 3/3 [==============================] - 0s 133ms/step - loss: 0.5584 - accuracy: 0.9071 - val_loss: 0.3855 - val_accuracy: 0.9192
# Epoch 3/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.4079 - accuracy: 0.9125 - val_loss: 0.2954 - val_accuracy: 0.9193
# Epoch 4/25
# 3/3 [==============================] - 0s 131ms/step - loss: 0.2995 - accuracy: 0.9134 - val_loss: 0.2433 - val_accuracy: 0.9241
# Epoch 5/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2417 - accuracy: 0.9162 - val_loss: 0.2798 - val_accuracy: 0.9320
# Epoch 6/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.2155 - accuracy: 0.9216 - val_loss: 0.2280 - val_accuracy: 0.9378
# Epoch 7/25
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1992 - accuracy: 0.9270 - val_loss: 0.2115 - val_accuracy: 0.9414
# Epoch 8/25
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1900 - accuracy: 0.9302 - val_loss: 0.2228 - val_accuracy: 0.9394
# Epoch 9/25
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1828 - accuracy: 0.9380 - val_loss: 0.1825 - val_accuracy: 0.9444
# Epoch 10/25
# 3/3 [==============================] - 0s 133ms/step - loss: 0.1709 - accuracy: 0.9410 - val_loss: 0.1731 - val_accuracy: 0.9458
# Epoch 11/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1640 - accuracy: 0.9426 - val_loss: 0.1604 - val_accuracy: 0.9472
# Epoch 12/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1584 - accuracy: 0.9458 - val_loss: 0.1684 - val_accuracy: 0.9392
# Epoch 13/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1552 - accuracy: 0.9471 - val_loss: 0.1513 - val_accuracy: 0.9425
# Epoch 14/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1516 - accuracy: 0.9482 - val_loss: 0.1530 - val_accuracy: 0.9415
# Epoch 15/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1492 - accuracy: 0.9486 - val_loss: 0.1467 - val_accuracy: 0.9458
# Epoch 16/25
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1467 - accuracy: 0.9497 - val_loss: 0.1467 - val_accuracy: 0.9457
# Epoch 17/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1444 - accuracy: 0.9503 - val_loss: 0.1369 - val_accuracy: 0.9506
# Epoch 18/25
# 3/3 [==============================] - 0s 135ms/step - loss: 0.1427 - accuracy: 0.9512 - val_loss: 0.1505 - val_accuracy: 0.9465
# Epoch 19/25
# 3/3 [==============================] - 0s 130ms/step - loss: 0.1439 - accuracy: 0.9501 - val_loss: 0.1295 - val_accuracy: 0.9537
# Epoch 20/25
# 3/3 [==============================] - 0s 131ms/step - loss: 0.1460 - accuracy: 0.9512 - val_loss: 0.1370 - val_accuracy: 0.9537
# Epoch 21/25
# 3/3 [==============================] - 0s 132ms/step - loss: 0.1418 - accuracy: 0.9521 - val_loss: 0.1419 - val_accuracy: 0.9515

# %%
#idx = random.randint(0, len(X_train))


preds_train = model.predict(X_train[:int(X_train.shape[0])], verbose=1)
# preds_test = model.predict(X_test, verbose=1)

 
preds_train_t = (preds_train > 0).astype(np.uint8)
# preds_test_t = (preds_test > 0).astype(np.uint8)
# Out:
# 1/1 [==============================] - 0s 23ms/step

# %% [markdown]
# ## Sanity check on some random training samples

# %%
ix = random.randint(0, len(preds_train_t)-1)
imshow(X_train[ix])
plt.show()
imshow(Y_train[ix])
plt.show()
imshow(np.squeeze(preds_train_t[ix]), cmap = "gray")
plt.show()

# %% [markdown]
# ## Sanity check on some random testing samples

# %%
ix = random.randint(0, len(preds_test_t) - 1)
imshow(X_test[ix])
plt.show()
imshow(np.squeeze(preds_test_t[ix]))
plt.show()
